// %%
%maven org.springframework.boot:spring-boot-starter-web:3.2.5

// %%
import org.springframework.boot.SpringApplication;
import org.springframework.boot.autoconfigure.SpringBootApplication;
import org.springframework.web.bind.annotation.GetMapping;
import org.springframework.web.bind.annotation.RestController;

import org.springframework.web.bind.annotation.RequestParam;

// %%
@SpringBootApplication
@RestController
public class springbootHelloWorld {



    @GetMapping("/")
    public String sayHi(@RequestParam(value = "name", defaultValue = "World") String name) {
        return "Hello, " + name + "!";
    }
}

// %%
var sb = SpringApplication.run(springbootHelloWorld.class);
// Out:
//   .   ____          _            __ _ _
//  /\\ / ___'_ __ _ _(_)_ __  __ _ \ \ \ \
// ( ( )\___ | '_ | '_| | '_ \/ _` | \ \ \ \
//  \\/  ___)| |_)| | | | | || (_| |  ) ) ) )
//   '  |____| .__|_| |_|_| |_\__, | / / / /
//  =========|_|==============|___/=/_/_/_/
//  :: Spring Boot ::                (v3.2.5)
//
// 2025-12-30T10:43:09.696Z  INFO 48 --- [Java-executor-1] o.s.boot.SpringApplication               : Starting application using Java 25.0.1 with PID 48 (started by jovyan in /home/jovyan/work/spring)
// 2025-12-30T10:43:09.697Z  INFO 48 --- [Java-executor-1] o.s.boot.SpringApplication               : No active profile set, falling back to 1 default profile: "default"
// 2025-12-30T10:43:10.059Z  INFO 48 --- [Java-executor-1] o.s.b.w.embedded.tomcat.TomcatWebServer  : Tomcat initialized with port 8080 (http)
// 2025-12-30T10:43:10.065Z  INFO 48 --- [Java-executor-1] o.apache.catalina.core.StandardService   : Starting service [Tomcat]
// 2025-12-30T10:43:10.065Z  INFO 48 --- [Java-executor-1] o.apache.catalina.core.StandardEngine    : Starting Servlet engine: [Apache Tomcat/10.1.20]
// 2025-12-30T10:43:10.081Z  INFO 48 --- [Java-executor-1] o.a.c.c.C.[Tomcat].[localhost].[/]       : Initializing Spring embedded WebApplicationContext
// 2025-12-30T10:43:10.081Z  INFO 48 --- [Java-executor-1] w.s.c.ServletWebServerApplicationContext : Root WebApplicationContext: initialization completed in 337 ms
// 2025-12-30T10:43:10.227Z  INFO 48 --- [Java-executor-1] o.s.b.w.embedded.tomcat.TomcatWebServer  : Tomcat started on port 8080 (http) with context path ''
// 2025-12-30T10:43:10.235Z  INFO 48 --- [Java-executor-1] o.s.boot.SpringApplication               : Started application in 0.714 seconds (process running for 163.41)

// %%
http://localhost:8080/
// Out:
// Incomplete input:
// |   http://localhost:8080/
