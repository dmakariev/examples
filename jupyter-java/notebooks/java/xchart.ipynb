// %%
%maven "org.knowm.xchart:xchart:3.5.2"

// %%
import org.knowm.xchart.*;

double[] xData = new double[] { 4.0, 1.0, 2.0 };
double[] yData = new double[] { 2.0, 1.0, 0.0 };

// %%
Arrays.asList(xData)
// Out:
// [[D@74b50864]

// %%
var chart = QuickChart.getChart("Sample Chart", "X", "Y", "y(x)", xData, yData);

// %%
BitmapEncoder.getBufferedImage(chart)
// Out:
// BufferedImage@2d99c5c6: type = 1 DirectColorModel: rmask=ff0000 gmask=ff00 bmask=ff amask=0 IntegerInterleavedRaster: width = 600 height = 400 #Bands = 3 xOff = 0 yOff = 0 dataOffset[0] 0
